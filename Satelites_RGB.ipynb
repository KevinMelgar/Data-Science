# %%
# !wget -c https://noaa-goes16.s3.amazonaws.com/ABI-L2-CMIPF/2022/203/18/OR_ABI-L2-CMIPF-M6C01_G16_s20222031820212_e20222031829520_c20222031829593.nc
# !wget -c https://noaa-goes16.s3.amazonaws.com/ABI-L2-CMIPF/2022/203/18/OR_ABI-L2-CMIPF-M6C02_G16_s20222031830212_e20222031839520_c20222031839588.nc
# !wget -c https://noaa-goes16.s3.amazonaws.com/ABI-L2-CMIPF/2022/203/18/OR_ABI-L2-CMIPF-M6C03_G16_s20222031830212_e20222031839520_c20222031839597.nc
# !wget -c https://noaa-goes16.s3.amazonaws.com/ABI-L2-CMIPF/2022/203/18/OR_ABI-L2-CMIPF-M6C04_G16_s20222031830212_e20222031839520_c20222031839579.nc
# Out:
# --2022-07-22 22:17:58--  https://noaa-goes16.s3.amazonaws.com/ABI-L2-CMIPF/2022/203/18/OR_ABI-L2-CMIPF-M6C01_G16_s20222031820212_e20222031829520_c20222031829593.nc
# Resolving noaa-goes16.s3.amazonaws.com (noaa-goes16.s3.amazonaws.com)... 52.216.89.236
# Connecting to noaa-goes16.s3.amazonaws.com (noaa-goes16.s3.amazonaws.com)|52.216.89.236|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 95713939 (91M) [binary/octet-stream]
# Saving to: ‘OR_ABI-L2-CMIPF-M6C01_G16_s20222031820212_e20222031829520_c20222031829593.nc’
#
# OR_ABI-L2-CMIPF-M6C 100%[===================>]  91.28M  27.6MB/s    in 3.3s
#
# 2022-07-22 22:18:02 (27.6 MB/s) - ‘OR_ABI-L2-CMIPF-M6C01_G16_s20222031820212_e20222031829520_c20222031829593.nc’ saved [95713939/95713939]
#
# --2022-07-22 22:18:02--  https://noaa-goes16.s3.amazonaws.com/ABI-L2-CMIPF/2022/203/18/OR_ABI-L2-CMIPF-M6C02_G16_s20222031830212_e20222031839520_c20222031839588.nc
# ...

# %%
# !wget -c https://noaa-goes16.s3.amazonaws.com/ABI-L2-CMIPF/2022/203/18/OR_ABI-L2-CMIPF-M6C05_G16_s20222031830212_e20222031839520_c20222031840009.nc
# !wget -c https://noaa-goes16.s3.amazonaws.com/ABI-L2-CMIPF/2022/203/18/OR_ABI-L2-CMIPF-M6C12_G16_s20222031830212_e20222031839525_c20222031840010.nc
# Out:
# --2022-07-22 22:55:46--  https://noaa-goes16.s3.amazonaws.com/ABI-L2-CMIPF/2022/203/18/OR_ABI-L2-CMIPF-M6C05_G16_s20222031830212_e20222031839520_c20222031840009.nc
# Resolving noaa-goes16.s3.amazonaws.com (noaa-goes16.s3.amazonaws.com)... 52.217.32.12
# Connecting to noaa-goes16.s3.amazonaws.com (noaa-goes16.s3.amazonaws.com)|52.217.32.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98902358 (94M) [binary/octet-stream]
# Saving to: ‘OR_ABI-L2-CMIPF-M6C05_G16_s20222031830212_e20222031839520_c20222031840009.nc’
#
# OR_ABI-L2-CMIPF-M6C 100%[===================>]  94.32M  27.9MB/s    in 3.4s
#
# 2022-07-22 22:55:50 (27.9 MB/s) - ‘OR_ABI-L2-CMIPF-M6C05_G16_s20222031830212_e20222031839520_c20222031840009.nc’ saved [98902358/98902358]
#
# --2022-07-22 22:55:50--  https://noaa-goes16.s3.amazonaws.com/ABI-L2-CMIPF/2022/203/18/OR_ABI-L2-CMIPF-M6C12_G16_s20222031830212_e20222031839525_c20222031840010.nc
# ...

# %%
import netCDF4 as nc

# %%
file1 = nc.Dataset('/content/OR_ABI-L2-CMIPF-M6C01_G16_s20222031820212_e20222031829520_c20222031829593.nc')
file2 = nc.Dataset('/content/OR_ABI-L2-CMIPF-M6C02_G16_s20222031830212_e20222031839520_c20222031839588.nc')
file3 = nc.Dataset('/content/OR_ABI-L2-CMIPF-M6C03_G16_s20222031830212_e20222031839520_c20222031839597.nc')
file4 = nc.Dataset('/content/OR_ABI-L2-CMIPF-M6C04_G16_s20222031830212_e20222031839520_c20222031839579.nc')

# %%
file5 = nc.Dataset('/content/OR_ABI-L2-CMIPF-M6C04_G16_s20222031830212_e20222031839520_c20222031839579.nc')
file12 = nc.Dataset('/content/OR_ABI-L2-CMIPF-M6C05_G16_s20222031830212_e20222031839520_c20222031840009.nc')

# %%
C1 = file1.variables['CMI'][::4,::4] #estoy sacando un segmento de la matrix, va saltando de 4 en 4
C2 = file2.variables['CMI'][::8,::8] #estoy sacando un segmento de la matrix, va saltando de 4 en 4
C3 = file3.variables['CMI'][::4,::4] #estoy sacando un segmento de la matrix, va saltando de 4 en 4
C4 = file4.variables['CMI'][::2,::2] #estoy sacando un segmento de la matrix, va saltando de 2 en 4
C5 = file5.variables['CMI'][::4,::4] #estoy sacando un segmento de la matrix, va saltando de 4 en 4
C12 = file12.variables['CMI'][::2,::2] #estoy sacando un segmento de la matrix, va saltando de 2 en 4
#datos1 = datosF-datosI

# %%
import numpy as np

# %%
np.shape(C1),np.shape(C2),np.shape(C3),np.shape(C4),np.shape(C5),np.shape(C12)
# Out:
# ((2712, 2712),
#  (2712, 2712),
#  (2712, 2712),
#  (2712, 2712),
#  (1356, 1356),
#  (5424, 5424))

# %%
COLORES=np.zeros((2712,2712,3))

# %%
COLORES[:,:,2]=C2
COLORES[:,:,0]=C5
COLORES[:,:,1]=C12
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-627b79f734a2> in <module>()
#       1 COLORES[:,:,2]=C2
# ----> 2 COLORES[:,:,0]=C5
#       3 COLORES[:,:,1]=C12
#
# ValueError: could not broadcast input array from shape (1356,1356) into shape (2712,2712)

# %%
import pylab as plt

# %%
plt.figure(figsize=(20,20))
plt.imshow(COLORES)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
